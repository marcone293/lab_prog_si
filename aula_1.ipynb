# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/david_lucasgs/aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from re import I
altura = 5.6
largura = 2.5
altura

peso = 78
altura = 1.70
peso / altura**2

imc = peso / altura**2
imc

nome = "david"

type (altura)
type (peso)
type (nome)

peso = 78
altura = 1.70
nome = "david"
professor = False
aluno = True
type (aluno)
type (professor)
# Out:
# bool

# %%
altura = 5.6

# %%
largura = 2.5

# %%
altura
# Out:
# 5.6

# %%
peso = 78

# %%
altura = 1.70

# %%
peso / altura**2
# Out:
# 26.989619377162633

# %%
imc = peso / altura**2

# %%
imc
# Out:
# 26.989619377162633

# %%
nome = "david"

# %%
type (altura)
# Out:
# float

# %%
type (peso)
# Out:
# int

# %%
type (nome)
# Out:
# str

# %%
peso = 78

# %%
altura = 1.70

# %%
nome = "david"

# %%
professor = False

# %%
aluno = True

# %%
type (aluno)
# Out:
# bool

# %%
type (professor)
# Out:
# bool

# %%
print(nome)
# Out:
# david

# %%
2 + 3
# Out:
# 5

# %%
"ab" + "cd"
# Out:
# 'abcd'

# %%
nome = "david "
nome1 = "yana"
nome2 = "ama a "
nome + nome2 + nome1
# Out:
# 'david ama a yana'

# %%
"1" + "1"
# Out:
# '11'

# %% [markdown]
# Questão 1

# %%
# exemplo
print(5/8)
# Out:
# 0.625

# %% [markdown]
# Questão 2

# %%
print(7 + 8)
# Out:
# 15

# %% [markdown]
# Questão 3

# %%
print(5 + 3)
print(5 - 3)
# Out:
# 8
# 2

# %% [markdown]
# Questão 4

# %%
print(5**3)
print(5*3)
print(5/3)
# Out:
# 125
# 15
# 1.6666666666666667

# %% [markdown]
# Questão 5

# %%
poupança = 100

# %%
multiplicador = 1.1

# %%
print(100 * 1.1**7)
# Out:
# 194.87171000000012

# %% [markdown]
# Questâo 6

# %%
poupança = 100

# %%
multiplicador = 1.1

# %%
desc = "juros simples"

# %%
ano1 = 1.1

# %%
print(ano1)
# Out:
# 1.1

# %%
print(type(ano1))
# Out:
# <class 'float'>

# %%
dubledesc = desc + desc

# %%
print(dubledesc)
# Out:
# juros simplesjuros simples

# %% [markdown]
# Questão 7

# %%
pi_string = "3.1415926"

# %%
pi_float = float(pi_string)
pi_float
# Out:
# 3.1415926

# %% [markdown]
# Questâo 8

# %%
poupança = 100

# %%
resultado = 100 * 1.1**7
print(resultado)
# Out:
# 194.87171000000012

# %%
sucesso = "eu comecei a economizar dinheiro na poupança e agora tenho dinheiro resultados incriveis"
print(sucesso)
# Out:
# eu comecei a economizar dinheiro na poupança e agora tenho dinheiro resultados incriveis

# %% [markdown]
# Questão 9

# %%
poupança = 100

# %%
resultado = 100 * 1.1**7
resultado
# Out:
# 194.87171000000012

# %%
string_resultado = str(resultado)
print(string_resultado)
# Out:
# 194.87171000000012

# %%
print("i said " + ("hey " * 2) + "hey!")
# Out:
# i said hey hey hey!
